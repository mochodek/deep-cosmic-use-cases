# %% [markdown]
# # Try DEEP-COSMIC-UC on your use cases

# %% [markdown]
# Train DEEP-COSMIC-UC and approximate size of your use cases

# %% [markdown]
# ## Imports

# %%
import pandas as pd

import itertools

import talos as ta

from gensim.models import KeyedVectors

from paths import input_folder, output_folder, word_embeddings_folder

from helpers import create_embedding_matrix, tokens2index, texts2index_padded, prune_wv

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import gc

from keras.models import Model
from keras.optimizers import Adam, Nadam
from keras.layers import TimeDistributed, GlobalMaxPooling1D, GlobalAveragePooling1D, Activation, Input, LSTM, GRU, Dense, Dropout, Flatten, Embedding, SpatialDropout1D, Bidirectional, CuDNNGRU
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D
from keras.layers.normalization import BatchNormalization
from keras.layers import Flatten, concatenate
from keras.engine.topology import Layer
from keras import initializers, regularizers, constraints, activations
from keras.layers.recurrent import Recurrent
from keras.engine import InputSpec
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau, CSVLogger
from keras.wrappers.scikit_learn import KerasRegressor

import spacy
from spacy.symbols import ORTH, LEMMA, POS, TAG, LOWER

from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, mean_absolute_error

import tensorflow as tf
from tensorflow import set_random_seed
from keras import backend as K

# This part required only for GPU
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.allocator_type = 'BFC'
sess = tf.Session(config=config)
K.set_session(sess)

random_seed = 102329

# %% [markdown]
# ## Load training data

# %% [markdown]
# Select projects that are similar to yours.

# %%
projects = ['P01',
 'P02',
 'P06',
 'P09',
 'P15',
 'P17',
 'P18',
 'P05',
 'P07',
 'P14',
 'P13',
 'P11',
 'P08',
 'P10',
 'P16',
 'P03',
 'P04',
 'P19',
 'P20',
 'P21',
 'P22',
 'P23',
 'P24',
 'P25',
 'P27',
 'P26',
 'P12']

# %%
use_cases_df = pd.read_csv(f"{input_folder}use-cases.csv", index_col=0)
use_cases_df.head(5)
# Out:
#   ProjectID        UC TransTypes   UCType  Cfp  \
# 0       P01   UC2-1-1    C|D|R|U  C|D|R|U   16
# 1       P01  UC2-1-10     DL|L|R        L   27
# 2       P01  UC2-1-11       CS|R       CS    7
# 3       P01  UC2-1-13    C|D|R|U  C|D|R|U   17
# 4       P01  UC2-1-14     DL|L|R        L   27
#
#                                          TitleTokens
# 0                              manage faculties crud
# 1  assign science olympiads major specialty edit ...
# 2                          manage ranking algorithms
# 3                                  manage exams crud
# 4        manage assignments exams majors specialties

# %%
use_cases_df = use_cases_df[use_cases_df['ProjectID'].isin(projects)]
use_cases_df.head(5)
# Out:
#   ProjectID        UC TransTypes   UCType  Cfp  \
# 0       P01   UC2-1-1    C|D|R|U  C|D|R|U   16
# 1       P01  UC2-1-10     DL|L|R        L   27
# 2       P01  UC2-1-11       CS|R       CS    7
# 3       P01  UC2-1-13    C|D|R|U  C|D|R|U   17
# 4       P01  UC2-1-14     DL|L|R        L   27
#
#                                          TitleTokens
# 0                              manage faculties crud
# 1  assign science olympiads major specialty edit ...
# 2                          manage ranking algorithms
# 3                                  manage exams crud
# 4        manage assignments exams majors specialties

# %%
tokenized_names = [name.split(" ") for name in use_cases_df['TitleTokens'].tolist()]

# %%
tokenized_names[:5]
# Out:
# [['manage', 'faculties', 'crud'],
#  ['assign', 'science', 'olympiads', 'major', 'specialty', 'edit', 'delete'],
#  ['manage', 'ranking', 'algorithms'],
#  ['manage', 'exams', 'crud'],
#  ['manage', 'assignments', 'exams', 'majors', 'specialties']]

# %%
train_ids = pd.read_csv(f"{input_folder}10-fold-train-full.csv", index_col=0)
val_ids = pd.read_csv(f"{input_folder}10-fold-val-full.csv", index_col=0)

runs = train_ids.run.max() + 1 
k = train_ids.k.max() + 1

# %% [markdown]
# ## Prepare your use cases

# %%
# add the names of your use cases here
use_cases = ["Add a paper.", "Delete a paper."]

# %%
nlp = spacy.load('en_core_web_lg')

stop_words = spacy.lang.en.stop_words.STOP_WORDS
filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'

# %%
titles = []
for text in use_cases:
    doc = nlp(text)
    tokens = " ".join([token.lower_ for token in doc if not token.orth_.isspace() and not token.orth_ in filters and not token.orth_ in stop_words])
    titles.append(tokens)

# %%
tokenized_pred_names = [name.split(" ") for name in titles]
tokenized_pred_names[:5]
# Out:
# [['add', 'paper'], ['delete', 'paper']]

# %%
tokenized_all_names = tokenized_pred_names + tokenized_names
tokenized_all_names[:10]
# Out:
# [['add', 'paper'],
#  ['delete', 'paper'],
#  ['manage', 'faculties', 'crud'],
#  ['assign', 'science', 'olympiads', 'major', 'specialty', 'edit', 'delete'],
#  ['manage', 'ranking', 'algorithms'],
#  ['manage', 'exams', 'crud'],
#  ['manage', 'assignments', 'exams', 'majors', 'specialties'],
#  ['manage', 'courses', 'crud'],
#  ['manage', 'assignments', 'courses', 'majors', 'specialties'],
#  ['manage', 'grading', 'scales', 'crud']]

# %% [markdown]
# ## DEEP-COSMIC-UC model

# %%
def get_deep_cosmic_uc_model():
        
    global MAX_SEQUENCE_LENGTH, embedding_matrix

    embedding_layer = Embedding(input_dim=embedding_matrix.shape[0],
                 output_dim=embedding_matrix.shape[1],
                 mask_zero=False,
                 weights=[embedding_matrix],
                 input_length=MAX_SEQUENCE_LENGTH,
                 trainable=False)

    line_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32', name="input")
    embedded_sequences = embedding_layer(line_input)
    cnn = Conv1D(filters=10, kernel_size=2, strides=1, 
                        padding='same', activation='relu')(embedded_sequences)
    cnn = MaxPooling1D(pool_size=2)(cnn)
    cnn = Conv1D(filters=12, kernel_size=2, strides=1, 
                        padding='same', activation='relu')(cnn)
    cnn = MaxPooling1D(pool_size=2)(cnn)
    cnn = Dropout(0.5)(cnn)
    cnn = GlobalAveragePooling1D()(cnn)

    output = Dense(1, activation='linear')(cnn)

    model = Model([line_input] , output)
    algorithm = Adam(lr=0.001, beta_1=0.95, beta_2=0.999, epsilon=1e-08, decay=0.0) #0.005

    model.compile(optimizer=algorithm, loss='mae', metrics=['mse','mae'])

    return model

# %%
wv = KeyedVectors.load_word2vec_format(f"{word_embeddings_folder}w2v_glove.6B.300d.txt", binary=False)

# %%
wv = prune_wv(wv, tokenized_all_names)
MAX_SEQUENCE_LENGTH, VECTOR_LENGTH = 16, wv.vector_size
embedding_matrix = create_embedding_matrix(wv, VECTOR_LENGTH)
embedding_matrix.shape
gc.collect()
# Out:
# 0

# %%
x = texts2index_padded(tokenized_names, wv, seq_length=MAX_SEQUENCE_LENGTH)
y = use_cases_df['Cfp']
# Out:
# 'oek' is not in the vocabulary - 'bind kek oek'
# 'oeks' is not in the vocabulary - 'report bindings oeks keks'
# 'keks' is not in the vocabulary - 'report bindings oeks keks'
# 'keks' is not in the vocabulary - 'report bindings keks modules'
# 'oek' is not in the vocabulary - 'add oek'
# 'swdpi' is not in the vocabulary - 'notifications desktop swdpi system user dashboard'

# %%
get_deep_cosmic_uc_model().summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 16)                0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 16, 300)           134100
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 16, 10)            6010
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 8, 10)             0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 8, 12)             252
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 4, 12)             0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 12)             0
# _________________________________________________________________
# global_average_pooling1d_5 ( (None, 12)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 140,375
# Trainable params: 6,275
# Non-trainable params: 134,100
# _________________________________________________________________

# %%
np.random.seed(random_seed)
set_random_seed(random_seed)

callbacks_list = [
    ReduceLROnPlateau( 
        monitor='loss',
        min_lr=0.001, 
        factor=0.5,
        verbose=1,
        patience=10) 
]

estimators = []
estimators.append(('cnn', KerasRegressor(build_fn=get_deep_cosmic_uc_model, epochs=400,
                                        batch_size=200, verbose=2, callbacks=callbacks_list))) 

model = Pipeline(estimators)

model.fit(x, y)
# Out:
# Epoch 1/400
#  - 0s - loss: 9.2690 - mean_squared_error: 125.2693 - mean_absolute_error: 9.2690
# Epoch 2/400
#  - 0s - loss: 9.2506 - mean_squared_error: 124.9250 - mean_absolute_error: 9.2506
# Epoch 3/400
#  - 0s - loss: 9.2308 - mean_squared_error: 124.5710 - mean_absolute_error: 9.2308
# Epoch 4/400
#  - 0s - loss: 9.2148 - mean_squared_error: 124.2741 - mean_absolute_error: 9.2148
# Epoch 5/400
#  - 0s - loss: 9.1968 - mean_squared_error: 123.9451 - mean_absolute_error: 9.1968
# Epoch 6/400
#  - 0s - loss: 9.1780 - mean_squared_error: 123.5751 - mean_absolute_error: 9.1780
# Epoch 7/400
#  - 0s - loss: 9.1531 - mean_squared_error: 123.1541 - mean_absolute_error: 9.1531
# Epoch 8/400
#  - 0s - loss: 9.1338 - mean_squared_error: 122.7814 - mean_absolute_error: 9.1338
# Epoch 9/400
#  - 0s - loss: 9.1123 - mean_squared_error: 122.3901 - mean_absolute_error: 9.1123
# Epoch 10/400
#  - 0s - loss: 9.0875 - mean_squared_error: 121.8882 - mean_absolute_error: 9.0875
# Epoch 11/400
#  - 0s - loss: 9.0524 - mean_squared_error: 121.3021 - mean_absolute_error: 9.0524
# Epoch 12/400
#  - 0s - loss: 9.0297 - mean_squared_error: 120.8490 - mean_absolute_error: 9.0297
# Epoch 13/400
#  - 0s - loss: 8.9931 - mean_squared_error: 120.2021 - mean_absolute_error: 8.9931
# Epoch 14/400
#  - 0s - loss: 8.9556 - mean_squared_error: 119.6268 - mean_absolute_error: 8.9556
# Epoch 15/400
#  - 0s - loss: 8.9178 - mean_squared_error: 118.8517 - mean_absolute_error: 8.9178
# Epoch 16/400
#  - 0s - loss: 8.8816 - mean_squared_error: 118.1450 - mean_absolute_error: 8.8816
# Epoch 17/400
#  - 0s - loss: 8.8272 - mean_squared_error: 117.2327 - mean_absolute_error: 8.8272
# Epoch 18/400
#  - 0s - loss: 8.7793 - mean_squared_error: 116.4193 - mean_absolute_error: 8.7793
# Epoch 19/400
#  - 0s - loss: 8.7456 - mean_squared_error: 115.8970 - mean_absolute_error: 8.7456
# Epoch 20/400
#  - 0s - loss: 8.6936 - mean_squared_error: 114.9477 - mean_absolute_error: 8.6936
# Epoch 21/400
#  - 0s - loss: 8.6235 - mean_squared_error: 113.7308 - mean_absolute_error: 8.6235
# Epoch 22/400
#  - 0s - loss: 8.5740 - mean_squared_error: 112.8385 - mean_absolute_error: 8.5740
# Epoch 23/400
#  - 0s - loss: 8.5073 - mean_squared_error: 111.7432 - mean_absolute_error: 8.5073
# Epoch 24/400
#  - 0s - loss: 8.4355 - mean_squared_error: 110.4507 - mean_absolute_error: 8.4355
# Epoch 25/400
#  - 0s - loss: 8.3779 - mean_squared_error: 109.3213 - mean_absolute_error: 8.3779
# Epoch 26/400
#  - 0s - loss: 8.3242 - mean_squared_error: 108.3696 - mean_absolute_error: 8.3242
# Epoch 27/400
#  - 0s - loss: 8.2291 - mean_squared_error: 106.9372 - mean_absolute_error: 8.2291
# Epoch 28/400
#  - 0s - loss: 8.1085 - mean_squared_error: 105.0795 - mean_absolute_error: 8.1085
# Epoch 29/400
#  - 0s - loss: 8.0534 - mean_squared_error: 103.5518 - mean_absolute_error: 8.0534
# Epoch 30/400
#  - 0s - loss: 7.9533 - mean_squared_error: 102.3902 - mean_absolute_error: 7.9533
# Epoch 31/400
#  - 0s - loss: 7.8606 - mean_squared_error: 101.1533 - mean_absolute_error: 7.8606
# Epoch 32/400
#  - 0s - loss: 7.7226 - mean_squared_error: 98.7652 - mean_absolute_error: 7.7226
# Epoch 33/400
#  - 0s - loss: 7.6394 - mean_squared_error: 97.3399 - mean_absolute_error: 7.6394
# Epoch 34/400
#  - 0s - loss: 7.5132 - mean_squared_error: 95.8222 - mean_absolute_error: 7.5132
# Epoch 35/400
#  - 0s - loss: 7.3983 - mean_squared_error: 93.7398 - mean_absolute_error: 7.3983
# Epoch 36/400
#  - 0s - loss: 7.2358 - mean_squared_error: 91.0064 - mean_absolute_error: 7.2358
# Epoch 37/400
#  - 0s - loss: 7.1203 - mean_squared_error: 89.6463 - mean_absolute_error: 7.1203
# Epoch 38/400
#  - 0s - loss: 6.9365 - mean_squared_error: 86.3614 - mean_absolute_error: 6.9365
# Epoch 39/400
#  - 0s - loss: 6.8317 - mean_squared_error: 85.0432 - mean_absolute_error: 6.8317
# Epoch 40/400
#  - 0s - loss: 6.6277 - mean_squared_error: 81.7170 - mean_absolute_error: 6.6277
# Epoch 41/400
#  - 0s - loss: 6.4847 - mean_squared_error: 80.3191 - mean_absolute_error: 6.4847
# Epoch 42/400
#  - 0s - loss: 6.2793 - mean_squared_error: 77.3705 - mean_absolute_error: 6.2793
# Epoch 43/400
#  - 0s - loss: 6.1185 - mean_squared_error: 75.3539 - mean_absolute_error: 6.1185
# Epoch 44/400
#  - 0s - loss: 5.9413 - mean_squared_error: 72.9768 - mean_absolute_error: 5.9413
# Epoch 45/400
#  - 0s - loss: 5.8112 - mean_squared_error: 70.3600 - mean_absolute_error: 5.8112
# Epoch 46/400
#  - 0s - loss: 5.6308 - mean_squared_error: 67.2772 - mean_absolute_error: 5.6308
# Epoch 47/400
#  - 0s - loss: 5.4965 - mean_squared_error: 65.5167 - mean_absolute_error: 5.4965
# Epoch 48/400
#  - 0s - loss: 5.3703 - mean_squared_error: 62.9976 - mean_absolute_error: 5.3703
# Epoch 49/400
#  - 0s - loss: 5.1868 - mean_squared_error: 60.4926 - mean_absolute_error: 5.1868
# Epoch 50/400
#  - 0s - loss: 5.0346 - mean_squared_error: 58.6306 - mean_absolute_error: 5.0346
# Epoch 51/400
#  - 0s - loss: 4.8883 - mean_squared_error: 55.8101 - mean_absolute_error: 4.8883
# Epoch 52/400
#  - 0s - loss: 4.7628 - mean_squared_error: 53.8486 - mean_absolute_error: 4.7628
# Epoch 53/400
#  - 0s - loss: 4.7740 - mean_squared_error: 52.7009 - mean_absolute_error: 4.7740
# Epoch 54/400
#  - 0s - loss: 4.6023 - mean_squared_error: 49.9877 - mean_absolute_error: 4.6023
# Epoch 55/400
#  - 0s - loss: 4.5662 - mean_squared_error: 48.4621 - mean_absolute_error: 4.5662
# Epoch 56/400
#  - 0s - loss: 4.7609 - mean_squared_error: 49.6340 - mean_absolute_error: 4.7609
# Epoch 57/400
#  - 0s - loss: 4.5912 - mean_squared_error: 48.2919 - mean_absolute_error: 4.5912
# Epoch 58/400
#  - 0s - loss: 4.6801 - mean_squared_error: 48.0637 - mean_absolute_error: 4.6801
# Epoch 59/400
#  - 0s - loss: 4.6058 - mean_squared_error: 47.2452 - mean_absolute_error: 4.6058
# Epoch 60/400
#  - 0s - loss: 4.6779 - mean_squared_error: 45.7325 - mean_absolute_error: 4.6779
# Epoch 61/400
#  - 0s - loss: 4.5248 - mean_squared_error: 43.7314 - mean_absolute_error: 4.5248
# Epoch 62/400
#  - 0s - loss: 4.5036 - mean_squared_error: 43.8261 - mean_absolute_error: 4.5036
# Epoch 63/400
#  - 0s - loss: 4.6173 - mean_squared_error: 43.9688 - mean_absolute_error: 4.6173
# Epoch 64/400
#  - 0s - loss: 4.4703 - mean_squared_error: 41.9485 - mean_absolute_error: 4.4703
# Epoch 65/400
#  - 0s - loss: 4.4548 - mean_squared_error: 42.6728 - mean_absolute_error: 4.4548
# Epoch 66/400
#  - 0s - loss: 4.4834 - mean_squared_error: 42.1823 - mean_absolute_error: 4.4834
# Epoch 67/400
#  - 0s - loss: 4.5653 - mean_squared_error: 43.1318 - mean_absolute_error: 4.5653
# Epoch 68/400
#  - 0s - loss: 4.3895 - mean_squared_error: 41.4656 - mean_absolute_error: 4.3895
# Epoch 69/400
#  - 0s - loss: 4.4532 - mean_squared_error: 41.6129 - mean_absolute_error: 4.4532
# Epoch 70/400
#  - 0s - loss: 4.4563 - mean_squared_error: 43.8306 - mean_absolute_error: 4.4563
# Epoch 71/400
#  - 0s - loss: 4.4021 - mean_squared_error: 40.8194 - mean_absolute_error: 4.4021
# Epoch 72/400
#  - 0s - loss: 4.3418 - mean_squared_error: 41.0933 - mean_absolute_error: 4.3418
# Epoch 73/400
#  - 0s - loss: 4.6491 - mean_squared_error: 43.5222 - mean_absolute_error: 4.6491
# Epoch 74/400
#  - 0s - loss: 4.4835 - mean_squared_error: 42.3896 - mean_absolute_error: 4.4835
# Epoch 75/400
#  - 0s - loss: 4.4931 - mean_squared_error: 43.0271 - mean_absolute_error: 4.4931
# Epoch 76/400
#  - 0s - loss: 4.4544 - mean_squared_error: 41.8552 - mean_absolute_error: 4.4544
# Epoch 77/400
#  - 0s - loss: 4.4426 - mean_squared_error: 42.0238 - mean_absolute_error: 4.4426
# Epoch 78/400
#  - 0s - loss: 4.2881 - mean_squared_error: 41.0180 - mean_absolute_error: 4.2881
# Epoch 79/400
#  - 0s - loss: 4.3854 - mean_squared_error: 42.1571 - mean_absolute_error: 4.3854
# Epoch 80/400
#  - 0s - loss: 4.2801 - mean_squared_error: 40.0670 - mean_absolute_error: 4.2801
# Epoch 81/400
#  - 0s - loss: 4.4240 - mean_squared_error: 42.3612 - mean_absolute_error: 4.4240
# Epoch 82/400
#  - 0s - loss: 4.2141 - mean_squared_error: 40.9539 - mean_absolute_error: 4.2141
# Epoch 83/400
#  - 0s - loss: 4.4570 - mean_squared_error: 43.5426 - mean_absolute_error: 4.4570
# Epoch 84/400
#  - 0s - loss: 4.2549 - mean_squared_error: 41.7316 - mean_absolute_error: 4.2549
# Epoch 85/400
#  - 0s - loss: 4.3461 - mean_squared_error: 41.6950 - mean_absolute_error: 4.3461
# Epoch 86/400
#  - 0s - loss: 4.3400 - mean_squared_error: 41.4131 - mean_absolute_error: 4.3400
# Epoch 87/400
#  - 0s - loss: 4.2678 - mean_squared_error: 42.7183 - mean_absolute_error: 4.2678
# Epoch 88/400
#  - 0s - loss: 4.3288 - mean_squared_error: 40.2552 - mean_absolute_error: 4.3288
# Epoch 89/400
#  - 0s - loss: 4.2669 - mean_squared_error: 39.9498 - mean_absolute_error: 4.2669
# Epoch 90/400
#  - 0s - loss: 4.3434 - mean_squared_error: 41.8776 - mean_absolute_error: 4.3434
# Epoch 91/400
#  - 0s - loss: 4.2436 - mean_squared_error: 40.0707 - mean_absolute_error: 4.2436
# Epoch 92/400
#  - 0s - loss: 4.4134 - mean_squared_error: 42.2024 - mean_absolute_error: 4.4134
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 93/400
#  - 0s - loss: 4.2952 - mean_squared_error: 40.6757 - mean_absolute_error: 4.2952
# Epoch 94/400
#  - 0s - loss: 4.3329 - mean_squared_error: 41.1915 - mean_absolute_error: 4.3329
# Epoch 95/400
#  - 0s - loss: 4.3446 - mean_squared_error: 42.2833 - mean_absolute_error: 4.3446
# Epoch 96/400
#  - 0s - loss: 4.2840 - mean_squared_error: 40.8078 - mean_absolute_error: 4.2840
# Epoch 97/400
#  - 0s - loss: 4.1772 - mean_squared_error: 38.6783 - mean_absolute_error: 4.1772
# Epoch 98/400
#  - 0s - loss: 4.1814 - mean_squared_error: 39.7179 - mean_absolute_error: 4.1814
# Epoch 99/400
#  - 0s - loss: 4.2840 - mean_squared_error: 39.9012 - mean_absolute_error: 4.2840
# Epoch 100/400
#  - 0s - loss: 4.2602 - mean_squared_error: 38.9501 - mean_absolute_error: 4.2602
# Epoch 101/400
#  - 0s - loss: 4.2367 - mean_squared_error: 39.4132 - mean_absolute_error: 4.2367
# Epoch 102/400
#  - 0s - loss: 4.2358 - mean_squared_error: 40.3668 - mean_absolute_error: 4.2358
# Epoch 103/400
#  - 0s - loss: 4.2208 - mean_squared_error: 40.6107 - mean_absolute_error: 4.2208
# Epoch 104/400
#  - 0s - loss: 4.3574 - mean_squared_error: 43.0711 - mean_absolute_error: 4.3574
# Epoch 105/400
#  - 0s - loss: 4.1905 - mean_squared_error: 39.2175 - mean_absolute_error: 4.1905
# Epoch 106/400
#  - 0s - loss: 4.1462 - mean_squared_error: 38.4066 - mean_absolute_error: 4.1462
# Epoch 107/400
#  - 0s - loss: 4.0392 - mean_squared_error: 39.5975 - mean_absolute_error: 4.0392
# Epoch 108/400
#  - 0s - loss: 4.1574 - mean_squared_error: 38.2767 - mean_absolute_error: 4.1574
# Epoch 109/400
#  - 0s - loss: 4.2081 - mean_squared_error: 39.6274 - mean_absolute_error: 4.2081
# Epoch 110/400
#  - 0s - loss: 4.0911 - mean_squared_error: 36.9339 - mean_absolute_error: 4.0911
# Epoch 111/400
#  - 0s - loss: 4.1064 - mean_squared_error: 36.8298 - mean_absolute_error: 4.1064
# Epoch 112/400
#  - 0s - loss: 4.0883 - mean_squared_error: 37.5109 - mean_absolute_error: 4.0883
# Epoch 113/400
#  - 0s - loss: 4.1400 - mean_squared_error: 37.6026 - mean_absolute_error: 4.1400
# Epoch 114/400
#  - 0s - loss: 4.1105 - mean_squared_error: 36.9127 - mean_absolute_error: 4.1105
# Epoch 115/400
#  - 0s - loss: 4.1151 - mean_squared_error: 37.6059 - mean_absolute_error: 4.1151
# Epoch 116/400
#  - 0s - loss: 4.1398 - mean_squared_error: 38.2845 - mean_absolute_error: 4.1398
# Epoch 117/400
#  - 0s - loss: 4.0910 - mean_squared_error: 37.1390 - mean_absolute_error: 4.0910
#
# Epoch 00117: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 118/400
#  - 0s - loss: 4.1350 - mean_squared_error: 37.7062 - mean_absolute_error: 4.1350
# Epoch 119/400
#  - 0s - loss: 4.2112 - mean_squared_error: 38.6045 - mean_absolute_error: 4.2112
# Epoch 120/400
#  - 0s - loss: 4.0950 - mean_squared_error: 37.2660 - mean_absolute_error: 4.0950
# Epoch 121/400
#  - 0s - loss: 4.0354 - mean_squared_error: 36.5421 - mean_absolute_error: 4.0354
# Epoch 122/400
#  - 0s - loss: 4.0474 - mean_squared_error: 37.0401 - mean_absolute_error: 4.0474
# Epoch 123/400
#  - 0s - loss: 4.0232 - mean_squared_error: 36.1211 - mean_absolute_error: 4.0232
# Epoch 124/400
#  - 0s - loss: 3.9282 - mean_squared_error: 34.6537 - mean_absolute_error: 3.9282
# Epoch 125/400
#  - 0s - loss: 3.9518 - mean_squared_error: 35.4652 - mean_absolute_error: 3.9518
# Epoch 126/400
#  - 0s - loss: 3.9753 - mean_squared_error: 36.0028 - mean_absolute_error: 3.9753
# Epoch 127/400
#  - 0s - loss: 3.9235 - mean_squared_error: 35.5600 - mean_absolute_error: 3.9235
# Epoch 128/400
#  - 0s - loss: 3.9133 - mean_squared_error: 34.2950 - mean_absolute_error: 3.9133
# Epoch 129/400
#  - 0s - loss: 3.9844 - mean_squared_error: 35.6012 - mean_absolute_error: 3.9844
# Epoch 130/400
#  - 0s - loss: 3.8684 - mean_squared_error: 34.2613 - mean_absolute_error: 3.8684
# Epoch 131/400
#  - 0s - loss: 3.9462 - mean_squared_error: 35.4417 - mean_absolute_error: 3.9462
# Epoch 132/400
#  - 0s - loss: 3.9616 - mean_squared_error: 35.8094 - mean_absolute_error: 3.9616
# Epoch 133/400
#  - 0s - loss: 3.9526 - mean_squared_error: 36.2581 - mean_absolute_error: 3.9526
# Epoch 134/400
#  - 0s - loss: 3.9385 - mean_squared_error: 34.9760 - mean_absolute_error: 3.9385
# Epoch 135/400
#  - 0s - loss: 3.8203 - mean_squared_error: 32.7685 - mean_absolute_error: 3.8203
# Epoch 136/400
#  - 0s - loss: 3.9770 - mean_squared_error: 36.0147 - mean_absolute_error: 3.9770
# Epoch 137/400
#  - 0s - loss: 4.0076 - mean_squared_error: 35.7401 - mean_absolute_error: 4.0076
# Epoch 138/400
#  - 0s - loss: 3.8189 - mean_squared_error: 33.2344 - mean_absolute_error: 3.8189
# Epoch 139/400
#  - 0s - loss: 3.8573 - mean_squared_error: 34.9529 - mean_absolute_error: 3.8573
# Epoch 140/400
#  - 0s - loss: 3.8827 - mean_squared_error: 34.7503 - mean_absolute_error: 3.8827
# Epoch 141/400
#  - 0s - loss: 3.9080 - mean_squared_error: 34.6433 - mean_absolute_error: 3.9080
# Epoch 142/400
#  - 0s - loss: 3.8755 - mean_squared_error: 34.7801 - mean_absolute_error: 3.8755
# Epoch 143/400
#  - 0s - loss: 3.8176 - mean_squared_error: 34.9130 - mean_absolute_error: 3.8176
# Epoch 144/400
#  - 0s - loss: 3.9081 - mean_squared_error: 35.4569 - mean_absolute_error: 3.9081
# Epoch 145/400
#  - 0s - loss: 3.9673 - mean_squared_error: 37.0385 - mean_absolute_error: 3.9673
# Epoch 146/400
#  - 0s - loss: 3.8454 - mean_squared_error: 34.4832 - mean_absolute_error: 3.8454
# Epoch 147/400
#  - 0s - loss: 4.0490 - mean_squared_error: 38.8749 - mean_absolute_error: 4.0490
# Epoch 148/400
#  - 0s - loss: 3.8619 - mean_squared_error: 34.8065 - mean_absolute_error: 3.8619
# Epoch 149/400
#  - 0s - loss: 3.7214 - mean_squared_error: 33.6175 - mean_absolute_error: 3.7214
# Epoch 150/400
#  - 0s - loss: 3.7624 - mean_squared_error: 33.3792 - mean_absolute_error: 3.7624
# Epoch 151/400
#  - 0s - loss: 3.9542 - mean_squared_error: 35.7482 - mean_absolute_error: 3.9542
# Epoch 152/400
#  - 0s - loss: 3.8641 - mean_squared_error: 33.6717 - mean_absolute_error: 3.8641
# Epoch 153/400
#  - 0s - loss: 3.7969 - mean_squared_error: 33.2045 - mean_absolute_error: 3.7969
# Epoch 154/400
#  - 0s - loss: 3.7713 - mean_squared_error: 33.3036 - mean_absolute_error: 3.7713
# Epoch 155/400
#  - 0s - loss: 3.6602 - mean_squared_error: 31.6422 - mean_absolute_error: 3.6602
# Epoch 156/400
#  - 0s - loss: 3.8244 - mean_squared_error: 34.0620 - mean_absolute_error: 3.8244
# Epoch 157/400
#  - 0s - loss: 3.7448 - mean_squared_error: 32.3569 - mean_absolute_error: 3.7448
# Epoch 158/400
#  - 0s - loss: 3.7067 - mean_squared_error: 30.5039 - mean_absolute_error: 3.7067
# Epoch 159/400
#  - 0s - loss: 3.6536 - mean_squared_error: 32.4990 - mean_absolute_error: 3.6536
# Epoch 160/400
#  - 0s - loss: 3.5991 - mean_squared_error: 29.9000 - mean_absolute_error: 3.5991
# Epoch 161/400
#  - 0s - loss: 3.6860 - mean_squared_error: 31.2458 - mean_absolute_error: 3.6860
# Epoch 162/400
#  - 0s - loss: 3.8449 - mean_squared_error: 34.2621 - mean_absolute_error: 3.8449
# Epoch 163/400
#  - 0s - loss: 3.8667 - mean_squared_error: 33.3419 - mean_absolute_error: 3.8667
# Epoch 164/400
#  - 0s - loss: 3.6629 - mean_squared_error: 31.2610 - mean_absolute_error: 3.6629
# Epoch 165/400
#  - 0s - loss: 3.7205 - mean_squared_error: 33.9583 - mean_absolute_error: 3.7205
# Epoch 166/400
#  - 0s - loss: 3.8298 - mean_squared_error: 32.8215 - mean_absolute_error: 3.8298
# Epoch 167/400
#  - 0s - loss: 3.7043 - mean_squared_error: 32.3548 - mean_absolute_error: 3.7043
# Epoch 168/400
#  - 0s - loss: 3.6838 - mean_squared_error: 32.0450 - mean_absolute_error: 3.6838
# Epoch 169/400
#  - 0s - loss: 3.6655 - mean_squared_error: 31.9505 - mean_absolute_error: 3.6655
# Epoch 170/400
#  - 0s - loss: 3.8313 - mean_squared_error: 33.3793 - mean_absolute_error: 3.8313
#
# Epoch 00170: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 171/400
#  - 0s - loss: 3.6906 - mean_squared_error: 31.2588 - mean_absolute_error: 3.6906
# Epoch 172/400
#  - 0s - loss: 3.7448 - mean_squared_error: 32.7984 - mean_absolute_error: 3.7448
# Epoch 173/400
#  - 0s - loss: 3.6327 - mean_squared_error: 31.0078 - mean_absolute_error: 3.6327
# Epoch 174/400
#  - 0s - loss: 3.6736 - mean_squared_error: 31.8726 - mean_absolute_error: 3.6736
# Epoch 175/400
#  - 0s - loss: 3.6339 - mean_squared_error: 31.9462 - mean_absolute_error: 3.6339
# Epoch 176/400
#  - 0s - loss: 3.7111 - mean_squared_error: 32.0066 - mean_absolute_error: 3.7111
# Epoch 177/400
#  - 0s - loss: 3.6317 - mean_squared_error: 30.7664 - mean_absolute_error: 3.6317
# Epoch 178/400
#  - 0s - loss: 3.7189 - mean_squared_error: 33.3736 - mean_absolute_error: 3.7189
# Epoch 179/400
#  - 0s - loss: 3.6632 - mean_squared_error: 31.1676 - mean_absolute_error: 3.6632
# Epoch 180/400
#  - 0s - loss: 3.7068 - mean_squared_error: 32.4194 - mean_absolute_error: 3.7068
#
# Epoch 00180: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 181/400
#  - 0s - loss: 3.6634 - mean_squared_error: 32.6888 - mean_absolute_error: 3.6634
# Epoch 182/400
#  - 0s - loss: 3.7135 - mean_squared_error: 33.0153 - mean_absolute_error: 3.7135
# Epoch 183/400
#  - 0s - loss: 3.5272 - mean_squared_error: 32.1436 - mean_absolute_error: 3.5272
# Epoch 184/400
#  - 0s - loss: 3.6315 - mean_squared_error: 32.0562 - mean_absolute_error: 3.6315
# Epoch 185/400
#  - 0s - loss: 3.6450 - mean_squared_error: 31.8608 - mean_absolute_error: 3.6450
# Epoch 186/400
#  - 0s - loss: 3.5881 - mean_squared_error: 31.6007 - mean_absolute_error: 3.5881
# Epoch 187/400
#  - 0s - loss: 3.6768 - mean_squared_error: 32.1271 - mean_absolute_error: 3.6768
# Epoch 188/400
#  - 0s - loss: 3.6006 - mean_squared_error: 31.5796 - mean_absolute_error: 3.6006
# Epoch 189/400
#  - 0s - loss: 3.5208 - mean_squared_error: 29.5969 - mean_absolute_error: 3.5208
# Epoch 190/400
#  - 0s - loss: 3.6039 - mean_squared_error: 30.8370 - mean_absolute_error: 3.6039
# Epoch 191/400
#  - 0s - loss: 3.6879 - mean_squared_error: 32.0584 - mean_absolute_error: 3.6879
# Epoch 192/400
#  - 0s - loss: 3.5373 - mean_squared_error: 28.8648 - mean_absolute_error: 3.5373
# Epoch 193/400
#  - 0s - loss: 3.6482 - mean_squared_error: 31.0562 - mean_absolute_error: 3.6482
# Epoch 194/400
#  - 0s - loss: 3.4817 - mean_squared_error: 30.0926 - mean_absolute_error: 3.4817
# Epoch 195/400
#  - 0s - loss: 3.5489 - mean_squared_error: 30.1528 - mean_absolute_error: 3.5489
# Epoch 196/400
#  - 0s - loss: 3.5203 - mean_squared_error: 28.9399 - mean_absolute_error: 3.5203
# Epoch 197/400
#  - 0s - loss: 3.5758 - mean_squared_error: 30.5270 - mean_absolute_error: 3.5758
# Epoch 198/400
#  - 0s - loss: 3.4844 - mean_squared_error: 29.4091 - mean_absolute_error: 3.4844
# Epoch 199/400
#  - 0s - loss: 3.4227 - mean_squared_error: 27.9892 - mean_absolute_error: 3.4227
# Epoch 200/400
#  - 0s - loss: 3.5186 - mean_squared_error: 29.7981 - mean_absolute_error: 3.5186
# Epoch 201/400
#  - 0s - loss: 3.6018 - mean_squared_error: 31.4762 - mean_absolute_error: 3.6018
# Epoch 202/400
#  - 0s - loss: 3.5456 - mean_squared_error: 29.3500 - mean_absolute_error: 3.5456
# Epoch 203/400
#  - 0s - loss: 3.5155 - mean_squared_error: 30.5486 - mean_absolute_error: 3.5155
# Epoch 204/400
#  - 0s - loss: 3.8081 - mean_squared_error: 32.5440 - mean_absolute_error: 3.8081
# Epoch 205/400
#  - 0s - loss: 3.4960 - mean_squared_error: 27.9593 - mean_absolute_error: 3.4960
# Epoch 206/400
#  - 0s - loss: 3.2423 - mean_squared_error: 27.8932 - mean_absolute_error: 3.2423
# Epoch 207/400
#  - 0s - loss: 3.3798 - mean_squared_error: 28.8186 - mean_absolute_error: 3.3798
# Epoch 208/400
#  - 0s - loss: 3.5779 - mean_squared_error: 30.4181 - mean_absolute_error: 3.5779
# Epoch 209/400
#  - 0s - loss: 3.5318 - mean_squared_error: 29.4363 - mean_absolute_error: 3.5318
# Epoch 210/400
#  - 0s - loss: 3.4997 - mean_squared_error: 30.0092 - mean_absolute_error: 3.4997
# Epoch 211/400
#  - 0s - loss: 3.4289 - mean_squared_error: 28.1080 - mean_absolute_error: 3.4289
# Epoch 212/400
#  - 0s - loss: 3.5107 - mean_squared_error: 31.4150 - mean_absolute_error: 3.5107
# Epoch 213/400
#  - 0s - loss: 3.4957 - mean_squared_error: 30.2806 - mean_absolute_error: 3.4957
# Epoch 214/400
#  - 0s - loss: 3.4225 - mean_squared_error: 27.2214 - mean_absolute_error: 3.4225
# Epoch 215/400
#  - 0s - loss: 3.3199 - mean_squared_error: 27.0066 - mean_absolute_error: 3.3199
# Epoch 216/400
#  - 0s - loss: 3.4436 - mean_squared_error: 28.6590 - mean_absolute_error: 3.4436
#
# Epoch 00216: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 217/400
#  - 0s - loss: 3.4723 - mean_squared_error: 29.7252 - mean_absolute_error: 3.4723
# Epoch 218/400
#  - 0s - loss: 3.3144 - mean_squared_error: 27.8242 - mean_absolute_error: 3.3144
# Epoch 219/400
#  - 0s - loss: 3.3898 - mean_squared_error: 27.0226 - mean_absolute_error: 3.3898
# Epoch 220/400
#  - 0s - loss: 3.4279 - mean_squared_error: 29.4211 - mean_absolute_error: 3.4279
# Epoch 221/400
#  - 0s - loss: 3.3740 - mean_squared_error: 28.9793 - mean_absolute_error: 3.3740
# Epoch 222/400
#  - 0s - loss: 3.5240 - mean_squared_error: 30.0736 - mean_absolute_error: 3.5240
# Epoch 223/400
#  - 0s - loss: 3.4310 - mean_squared_error: 29.8571 - mean_absolute_error: 3.4310
# Epoch 224/400
#  - 0s - loss: 3.5429 - mean_squared_error: 29.2383 - mean_absolute_error: 3.5429
# Epoch 225/400
#  - 0s - loss: 3.5083 - mean_squared_error: 29.8849 - mean_absolute_error: 3.5083
# Epoch 226/400
#  - 0s - loss: 3.3001 - mean_squared_error: 27.8511 - mean_absolute_error: 3.3001
#
# Epoch 00226: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 227/400
#  - 0s - loss: 3.3864 - mean_squared_error: 29.3884 - mean_absolute_error: 3.3864
# Epoch 228/400
#  - 0s - loss: 3.3201 - mean_squared_error: 28.9807 - mean_absolute_error: 3.3201
# Epoch 229/400
#  - 0s - loss: 3.3909 - mean_squared_error: 27.9556 - mean_absolute_error: 3.3909
# Epoch 230/400
#  - 0s - loss: 3.3712 - mean_squared_error: 28.8771 - mean_absolute_error: 3.3712
# Epoch 231/400
#  - 0s - loss: 3.4331 - mean_squared_error: 28.6263 - mean_absolute_error: 3.4331
# Epoch 232/400
#  - 0s - loss: 3.5370 - mean_squared_error: 30.3393 - mean_absolute_error: 3.5370
# Epoch 233/400
#  - 0s - loss: 3.3022 - mean_squared_error: 28.2056 - mean_absolute_error: 3.3022
# Epoch 234/400
#  - 0s - loss: 3.3846 - mean_squared_error: 29.2873 - mean_absolute_error: 3.3846
# Epoch 235/400
#  - 0s - loss: 3.4522 - mean_squared_error: 30.8276 - mean_absolute_error: 3.4522
# Epoch 236/400
#  - 0s - loss: 3.3842 - mean_squared_error: 28.3736 - mean_absolute_error: 3.3842
#
# Epoch 00236: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 237/400
#  - 0s - loss: 3.1690 - mean_squared_error: 24.4956 - mean_absolute_error: 3.1690
# Epoch 238/400
#  - 0s - loss: 3.3262 - mean_squared_error: 27.0129 - mean_absolute_error: 3.3262
# Epoch 239/400
#  - 0s - loss: 3.5006 - mean_squared_error: 28.5597 - mean_absolute_error: 3.5006
# Epoch 240/400
#  - 0s - loss: 3.4736 - mean_squared_error: 28.7745 - mean_absolute_error: 3.4736
# Epoch 241/400
#  - 0s - loss: 3.3292 - mean_squared_error: 26.9632 - mean_absolute_error: 3.3292
# Epoch 242/400
#  - 0s - loss: 3.2477 - mean_squared_error: 25.7506 - mean_absolute_error: 3.2477
# Epoch 243/400
#  - 0s - loss: 3.4305 - mean_squared_error: 27.0625 - mean_absolute_error: 3.4305
# Epoch 244/400
#  - 0s - loss: 3.4275 - mean_squared_error: 27.5297 - mean_absolute_error: 3.4275
# Epoch 245/400
#  - 0s - loss: 3.2730 - mean_squared_error: 27.4413 - mean_absolute_error: 3.2730
# Epoch 246/400
#  - 0s - loss: 3.3427 - mean_squared_error: 27.1752 - mean_absolute_error: 3.3427
# Epoch 247/400
#  - 0s - loss: 3.2605 - mean_squared_error: 27.9273 - mean_absolute_error: 3.2605
#
# Epoch 00247: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 248/400
#  - 0s - loss: 3.4304 - mean_squared_error: 29.2104 - mean_absolute_error: 3.4304
# Epoch 249/400
#  - 0s - loss: 3.4050 - mean_squared_error: 29.6491 - mean_absolute_error: 3.4050
# Epoch 250/400
#  - 0s - loss: 3.3127 - mean_squared_error: 27.2486 - mean_absolute_error: 3.3127
# Epoch 251/400
#  - 0s - loss: 3.3296 - mean_squared_error: 28.6474 - mean_absolute_error: 3.3296
# Epoch 252/400
#  - 0s - loss: 3.4211 - mean_squared_error: 29.5368 - mean_absolute_error: 3.4211
# Epoch 253/400
#  - 0s - loss: 3.3516 - mean_squared_error: 28.4049 - mean_absolute_error: 3.3516
# Epoch 254/400
#  - 0s - loss: 3.1456 - mean_squared_error: 25.0376 - mean_absolute_error: 3.1456
# Epoch 255/400
#  - 0s - loss: 3.2229 - mean_squared_error: 26.7785 - mean_absolute_error: 3.2229
# Epoch 256/400
#  - 0s - loss: 3.3120 - mean_squared_error: 28.9947 - mean_absolute_error: 3.3120
# Epoch 257/400
#  - 0s - loss: 3.3008 - mean_squared_error: 28.2269 - mean_absolute_error: 3.3008
# Epoch 258/400
#  - 0s - loss: 3.3836 - mean_squared_error: 28.2622 - mean_absolute_error: 3.3836
# Epoch 259/400
#  - 0s - loss: 3.4499 - mean_squared_error: 29.3267 - mean_absolute_error: 3.4499
# Epoch 260/400
#  - 0s - loss: 3.2785 - mean_squared_error: 25.9453 - mean_absolute_error: 3.2785
# Epoch 261/400
#  - 0s - loss: 3.2413 - mean_squared_error: 27.2614 - mean_absolute_error: 3.2413
# Epoch 262/400
#  - 0s - loss: 3.3753 - mean_squared_error: 27.6347 - mean_absolute_error: 3.3753
# Epoch 263/400
#  - 0s - loss: 3.3565 - mean_squared_error: 27.4701 - mean_absolute_error: 3.3565
# Epoch 264/400
#  - 0s - loss: 3.3197 - mean_squared_error: 27.3342 - mean_absolute_error: 3.3197
#
# Epoch 00264: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 265/400
#  - 0s - loss: 3.2147 - mean_squared_error: 27.2686 - mean_absolute_error: 3.2147
# Epoch 266/400
#  - 0s - loss: 3.1971 - mean_squared_error: 25.8249 - mean_absolute_error: 3.1971
# Epoch 267/400
#  - 0s - loss: 3.3891 - mean_squared_error: 27.6537 - mean_absolute_error: 3.3891
# Epoch 268/400
#  - 0s - loss: 3.2166 - mean_squared_error: 25.9951 - mean_absolute_error: 3.2166
# Epoch 269/400
#  - 0s - loss: 3.1999 - mean_squared_error: 26.9129 - mean_absolute_error: 3.1999
# Epoch 270/400
#  - 0s - loss: 3.3259 - mean_squared_error: 29.2488 - mean_absolute_error: 3.3259
# Epoch 271/400
#  - 0s - loss: 3.3385 - mean_squared_error: 26.6806 - mean_absolute_error: 3.3385
# Epoch 272/400
#  - 0s - loss: 3.1889 - mean_squared_error: 24.7195 - mean_absolute_error: 3.1889
# Epoch 273/400
#  - 0s - loss: 3.3006 - mean_squared_error: 26.7648 - mean_absolute_error: 3.3006
# Epoch 274/400
#  - 0s - loss: 3.2410 - mean_squared_error: 26.7746 - mean_absolute_error: 3.2410
#
# Epoch 00274: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 275/400
#  - 0s - loss: 3.2546 - mean_squared_error: 25.7341 - mean_absolute_error: 3.2546
# Epoch 276/400
#  - 0s - loss: 3.1921 - mean_squared_error: 25.3174 - mean_absolute_error: 3.1921
# Epoch 277/400
#  - 0s - loss: 3.2862 - mean_squared_error: 27.3184 - mean_absolute_error: 3.2862
# Epoch 278/400
#  - 0s - loss: 3.2894 - mean_squared_error: 26.3797 - mean_absolute_error: 3.2894
# Epoch 279/400
#  - 0s - loss: 3.1756 - mean_squared_error: 25.2668 - mean_absolute_error: 3.1756
# Epoch 280/400
#  - 0s - loss: 3.2773 - mean_squared_error: 27.0970 - mean_absolute_error: 3.2773
# Epoch 281/400
#  - 0s - loss: 3.2157 - mean_squared_error: 27.6572 - mean_absolute_error: 3.2157
# Epoch 282/400
#  - 0s - loss: 3.2440 - mean_squared_error: 28.2779 - mean_absolute_error: 3.2440
# Epoch 283/400
#  - 0s - loss: 3.3495 - mean_squared_error: 28.5343 - mean_absolute_error: 3.3495
# Epoch 284/400
#  - 0s - loss: 3.2397 - mean_squared_error: 25.5458 - mean_absolute_error: 3.2397
#
# Epoch 00284: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 285/400
#  - 0s - loss: 3.2289 - mean_squared_error: 26.8423 - mean_absolute_error: 3.2289
# Epoch 286/400
#  - 0s - loss: 3.2119 - mean_squared_error: 25.1045 - mean_absolute_error: 3.2119
# Epoch 287/400
#  - 0s - loss: 3.2072 - mean_squared_error: 27.6728 - mean_absolute_error: 3.2072
# Epoch 288/400
#  - 0s - loss: 3.1313 - mean_squared_error: 26.0545 - mean_absolute_error: 3.1313
# Epoch 289/400
#  - 0s - loss: 3.0958 - mean_squared_error: 24.6654 - mean_absolute_error: 3.0958
# Epoch 290/400
#  - 0s - loss: 3.1005 - mean_squared_error: 26.0779 - mean_absolute_error: 3.1005
# Epoch 291/400
#  - 0s - loss: 3.1953 - mean_squared_error: 26.6264 - mean_absolute_error: 3.1953
# Epoch 292/400
#  - 0s - loss: 3.3171 - mean_squared_error: 28.7579 - mean_absolute_error: 3.3171
# Epoch 293/400
#  - 0s - loss: 3.1730 - mean_squared_error: 25.5170 - mean_absolute_error: 3.1730
# Epoch 294/400
#  - 0s - loss: 3.1197 - mean_squared_error: 26.9043 - mean_absolute_error: 3.1197
# Epoch 295/400
#  - 0s - loss: 3.2492 - mean_squared_error: 26.2254 - mean_absolute_error: 3.2492
# Epoch 296/400
#  - 0s - loss: 3.2319 - mean_squared_error: 27.0918 - mean_absolute_error: 3.2319
# Epoch 297/400
#  - 0s - loss: 3.0350 - mean_squared_error: 23.6634 - mean_absolute_error: 3.0350
# Epoch 298/400
#  - 0s - loss: 3.1902 - mean_squared_error: 26.2048 - mean_absolute_error: 3.1902
# Epoch 299/400
#  - 0s - loss: 3.1360 - mean_squared_error: 25.5001 - mean_absolute_error: 3.1360
# Epoch 300/400
#  - 0s - loss: 3.0945 - mean_squared_error: 25.0081 - mean_absolute_error: 3.0945
# Epoch 301/400
#  - 0s - loss: 3.2315 - mean_squared_error: 26.8463 - mean_absolute_error: 3.2315
# Epoch 302/400
#  - 0s - loss: 3.1712 - mean_squared_error: 25.8835 - mean_absolute_error: 3.1712
# Epoch 303/400
#  - 0s - loss: 3.2762 - mean_squared_error: 27.1789 - mean_absolute_error: 3.2762
# Epoch 304/400
#  - 0s - loss: 3.0800 - mean_squared_error: 25.0366 - mean_absolute_error: 3.0800
# Epoch 305/400
#  - 0s - loss: 3.1190 - mean_squared_error: 25.8936 - mean_absolute_error: 3.1190
# Epoch 306/400
#  - 0s - loss: 3.2234 - mean_squared_error: 26.0845 - mean_absolute_error: 3.2234
# Epoch 307/400
#  - 0s - loss: 3.1084 - mean_squared_error: 25.9335 - mean_absolute_error: 3.1084
#
# Epoch 00307: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 308/400
#  - 0s - loss: 3.1259 - mean_squared_error: 24.9394 - mean_absolute_error: 3.1259
# Epoch 309/400
#  - 0s - loss: 3.1093 - mean_squared_error: 24.4313 - mean_absolute_error: 3.1093
# Epoch 310/400
#  - 0s - loss: 3.1516 - mean_squared_error: 24.2080 - mean_absolute_error: 3.1516
# Epoch 311/400
#  - 0s - loss: 3.0642 - mean_squared_error: 24.9106 - mean_absolute_error: 3.0642
# Epoch 312/400
#  - 0s - loss: 3.0493 - mean_squared_error: 24.6578 - mean_absolute_error: 3.0493
# Epoch 313/400
#  - 0s - loss: 3.0742 - mean_squared_error: 23.9658 - mean_absolute_error: 3.0742
# Epoch 314/400
#  - 0s - loss: 3.0280 - mean_squared_error: 22.6820 - mean_absolute_error: 3.0280
# Epoch 315/400
#  - 0s - loss: 3.0579 - mean_squared_error: 25.5922 - mean_absolute_error: 3.0579
# Epoch 316/400
#  - 0s - loss: 3.0680 - mean_squared_error: 22.7868 - mean_absolute_error: 3.0680
# Epoch 317/400
#  - 0s - loss: 3.1534 - mean_squared_error: 26.9838 - mean_absolute_error: 3.1534
# Epoch 318/400
#  - 0s - loss: 3.1158 - mean_squared_error: 24.0030 - mean_absolute_error: 3.1158
# Epoch 319/400
#  - 0s - loss: 3.2182 - mean_squared_error: 27.6024 - mean_absolute_error: 3.2182
# Epoch 320/400
#  - 0s - loss: 3.1477 - mean_squared_error: 25.6310 - mean_absolute_error: 3.1477
# Epoch 321/400
#  - 0s - loss: 3.1949 - mean_squared_error: 26.8724 - mean_absolute_error: 3.1949
# Epoch 322/400
#  - 0s - loss: 3.2335 - mean_squared_error: 25.9920 - mean_absolute_error: 3.2335
# Epoch 323/400
#  - 0s - loss: 3.1887 - mean_squared_error: 26.9639 - mean_absolute_error: 3.1887
# Epoch 324/400
#  - 0s - loss: 3.1282 - mean_squared_error: 24.0934 - mean_absolute_error: 3.1282
#
# Epoch 00324: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 325/400
#  - 0s - loss: 3.0619 - mean_squared_error: 24.3590 - mean_absolute_error: 3.0619
# Epoch 326/400
#  - 0s - loss: 3.1845 - mean_squared_error: 25.1606 - mean_absolute_error: 3.1845
# Epoch 327/400
#  - 0s - loss: 2.9434 - mean_squared_error: 23.3427 - mean_absolute_error: 2.9434
# Epoch 328/400
#  - 0s - loss: 3.0473 - mean_squared_error: 24.8919 - mean_absolute_error: 3.0473
# Epoch 329/400
#  - 0s - loss: 3.1166 - mean_squared_error: 26.3935 - mean_absolute_error: 3.1166
# Epoch 330/400
#  - 0s - loss: 2.9688 - mean_squared_error: 22.3227 - mean_absolute_error: 2.9688
# Epoch 331/400
#  - 0s - loss: 3.1273 - mean_squared_error: 26.0026 - mean_absolute_error: 3.1273
# Epoch 332/400
#  - 0s - loss: 3.1789 - mean_squared_error: 24.9645 - mean_absolute_error: 3.1789
# Epoch 333/400
#  - 0s - loss: 2.9034 - mean_squared_error: 21.7526 - mean_absolute_error: 2.9034
# Epoch 334/400
#  - 0s - loss: 3.1002 - mean_squared_error: 25.1865 - mean_absolute_error: 3.1002
# Epoch 335/400
#  - 0s - loss: 3.1694 - mean_squared_error: 25.9961 - mean_absolute_error: 3.1694
# Epoch 336/400
#  - 0s - loss: 3.0644 - mean_squared_error: 25.3328 - mean_absolute_error: 3.0644
# Epoch 337/400
#  - 0s - loss: 3.0237 - mean_squared_error: 24.6773 - mean_absolute_error: 3.0237
# Epoch 338/400
#  - 0s - loss: 3.0397 - mean_squared_error: 23.5624 - mean_absolute_error: 3.0397
# Epoch 339/400
#  - 0s - loss: 3.1537 - mean_squared_error: 25.6258 - mean_absolute_error: 3.1537
# Epoch 340/400
#  - 0s - loss: 2.9804 - mean_squared_error: 24.3230 - mean_absolute_error: 2.9804
# Epoch 341/400
#  - 0s - loss: 3.0826 - mean_squared_error: 25.2882 - mean_absolute_error: 3.0826
# Epoch 342/400
#  - 0s - loss: 3.0245 - mean_squared_error: 25.4349 - mean_absolute_error: 3.0245
# Epoch 343/400
#  - 0s - loss: 2.9893 - mean_squared_error: 23.4456 - mean_absolute_error: 2.9893
#
# Epoch 00343: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 344/400
#  - 0s - loss: 3.1414 - mean_squared_error: 26.1211 - mean_absolute_error: 3.1414
# Epoch 345/400
#  - 0s - loss: 3.1080 - mean_squared_error: 25.4939 - mean_absolute_error: 3.1080
# Epoch 346/400
#  - 0s - loss: 3.1478 - mean_squared_error: 24.4498 - mean_absolute_error: 3.1478
# Epoch 347/400
#  - 0s - loss: 3.0781 - mean_squared_error: 24.7206 - mean_absolute_error: 3.0781
# Epoch 348/400
#  - 0s - loss: 3.0239 - mean_squared_error: 24.3202 - mean_absolute_error: 3.0239
# Epoch 349/400
#  - 0s - loss: 3.0629 - mean_squared_error: 25.5404 - mean_absolute_error: 3.0629
# Epoch 350/400
#  - 0s - loss: 3.1484 - mean_squared_error: 24.3784 - mean_absolute_error: 3.1484
# Epoch 351/400
#  - 0s - loss: 3.1207 - mean_squared_error: 24.4446 - mean_absolute_error: 3.1207
# Epoch 352/400
#  - 0s - loss: 3.1083 - mean_squared_error: 26.3143 - mean_absolute_error: 3.1083
# Epoch 353/400
#  - 0s - loss: 2.9165 - mean_squared_error: 23.3876 - mean_absolute_error: 2.9165
#
# Epoch 00353: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 354/400
#  - 0s - loss: 3.1621 - mean_squared_error: 25.8245 - mean_absolute_error: 3.1621
# Epoch 355/400
#  - 0s - loss: 3.0815 - mean_squared_error: 24.4936 - mean_absolute_error: 3.0815
# Epoch 356/400
#  - 0s - loss: 2.9666 - mean_squared_error: 23.4713 - mean_absolute_error: 2.9666
# Epoch 357/400
#  - 0s - loss: 2.9831 - mean_squared_error: 22.4649 - mean_absolute_error: 2.9831
# Epoch 358/400
#  - 0s - loss: 2.9774 - mean_squared_error: 23.3160 - mean_absolute_error: 2.9774
# Epoch 359/400
#  - 0s - loss: 3.0738 - mean_squared_error: 24.8509 - mean_absolute_error: 3.0738
# Epoch 360/400
#  - 0s - loss: 2.9504 - mean_squared_error: 23.7626 - mean_absolute_error: 2.9504
# Epoch 361/400
#  - 0s - loss: 2.9374 - mean_squared_error: 24.5206 - mean_absolute_error: 2.9374
# Epoch 362/400
#  - 0s - loss: 2.9393 - mean_squared_error: 23.6551 - mean_absolute_error: 2.9393
# Epoch 363/400
#  - 0s - loss: 2.9935 - mean_squared_error: 23.6269 - mean_absolute_error: 2.9935
#
# Epoch 00363: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 364/400
#  - 0s - loss: 2.9176 - mean_squared_error: 22.7147 - mean_absolute_error: 2.9176
# Epoch 365/400
#  - 0s - loss: 2.9785 - mean_squared_error: 23.9176 - mean_absolute_error: 2.9785
# Epoch 366/400
#  - 0s - loss: 2.9893 - mean_squared_error: 25.2785 - mean_absolute_error: 2.9893
# Epoch 367/400
#  - 0s - loss: 2.9316 - mean_squared_error: 21.7036 - mean_absolute_error: 2.9316
# Epoch 368/400
#  - 0s - loss: 2.8769 - mean_squared_error: 21.7849 - mean_absolute_error: 2.8769
# Epoch 369/400
#  - 0s - loss: 2.9523 - mean_squared_error: 22.7090 - mean_absolute_error: 2.9523
# Epoch 370/400
#  - 0s - loss: 2.9255 - mean_squared_error: 23.5123 - mean_absolute_error: 2.9255
# Epoch 371/400
#  - 0s - loss: 2.9688 - mean_squared_error: 24.2600 - mean_absolute_error: 2.9688
# Epoch 372/400
#  - 0s - loss: 3.0870 - mean_squared_error: 23.5890 - mean_absolute_error: 3.0870
# Epoch 373/400
#  - 0s - loss: 3.1025 - mean_squared_error: 25.2551 - mean_absolute_error: 3.1025
# Epoch 374/400
#  - 0s - loss: 2.9239 - mean_squared_error: 23.7743 - mean_absolute_error: 2.9239
# Epoch 375/400
#  - 0s - loss: 2.9174 - mean_squared_error: 22.4220 - mean_absolute_error: 2.9174
# Epoch 376/400
#  - 0s - loss: 2.9408 - mean_squared_error: 23.5253 - mean_absolute_error: 2.9408
# Epoch 377/400
#  - 0s - loss: 2.9358 - mean_squared_error: 22.3319 - mean_absolute_error: 2.9358
# Epoch 378/400
#  - 0s - loss: 3.0343 - mean_squared_error: 24.8099 - mean_absolute_error: 3.0343
#
# Epoch 00378: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 379/400
#  - 0s - loss: 3.0070 - mean_squared_error: 24.4087 - mean_absolute_error: 3.0070
# Epoch 380/400
#  - 0s - loss: 2.9562 - mean_squared_error: 22.3729 - mean_absolute_error: 2.9562
# Epoch 381/400
#  - 0s - loss: 2.9423 - mean_squared_error: 23.6012 - mean_absolute_error: 2.9423
# Epoch 382/400
#  - 0s - loss: 2.9442 - mean_squared_error: 23.5592 - mean_absolute_error: 2.9442
# Epoch 383/400
#  - 0s - loss: 2.9887 - mean_squared_error: 23.8571 - mean_absolute_error: 2.9887
# Epoch 384/400
#  - 0s - loss: 2.9753 - mean_squared_error: 23.3545 - mean_absolute_error: 2.9753
# Epoch 385/400
#  - 0s - loss: 2.7717 - mean_squared_error: 21.8554 - mean_absolute_error: 2.7717
# Epoch 386/400
#  - 0s - loss: 3.0153 - mean_squared_error: 23.0458 - mean_absolute_error: 3.0153
# Epoch 387/400
#  - 0s - loss: 3.0034 - mean_squared_error: 22.3823 - mean_absolute_error: 3.0034
# Epoch 388/400
#  - 0s - loss: 2.8907 - mean_squared_error: 23.1972 - mean_absolute_error: 2.8907
# Epoch 389/400
#  - 0s - loss: 2.9355 - mean_squared_error: 24.8130 - mean_absolute_error: 2.9355
# Epoch 390/400
#  - 0s - loss: 2.8873 - mean_squared_error: 23.2823 - mean_absolute_error: 2.8873
# Epoch 391/400
#  - 0s - loss: 2.8496 - mean_squared_error: 22.9989 - mean_absolute_error: 2.8496
# Epoch 392/400
#  - 0s - loss: 2.8317 - mean_squared_error: 21.0265 - mean_absolute_error: 2.8317
# Epoch 393/400
#  - 0s - loss: 2.9082 - mean_squared_error: 22.2394 - mean_absolute_error: 2.9082
# Epoch 394/400
#  - 0s - loss: 2.9386 - mean_squared_error: 23.5708 - mean_absolute_error: 2.9386
# Epoch 395/400
#  - 0s - loss: 2.7001 - mean_squared_error: 20.8411 - mean_absolute_error: 2.7001
# Epoch 396/400
#  - 0s - loss: 2.9233 - mean_squared_error: 21.7583 - mean_absolute_error: 2.9233
# Epoch 397/400
#  - 0s - loss: 3.0208 - mean_squared_error: 24.3775 - mean_absolute_error: 3.0208
# Epoch 398/400
#  - 0s - loss: 2.9114 - mean_squared_error: 20.6885 - mean_absolute_error: 2.9114
# Epoch 399/400
#  - 0s - loss: 2.9027 - mean_squared_error: 22.1452 - mean_absolute_error: 2.9027
# Epoch 400/400
#  - 0s - loss: 2.9655 - mean_squared_error: 21.7931 - mean_absolute_error: 2.9655
# Pipeline(memory=None,
#      steps=[('cnn', <keras.wrappers.scikit_learn.KerasRegressor object at 0x000001464C5AA358>)])

# %% [markdown]
# ## Predict size of use cases

# %%
x_pred = texts2index_padded(tokenized_pred_names, wv, seq_length=MAX_SEQUENCE_LENGTH)

# %%
y_pred = model.predict(x_pred)

# %%
predictions = pd.DataFrame({'use case':use_cases, 'Cfp-pred':y_pred, 'Cfp-int':np.round(y_pred)})

# %%
predictions
# Out:
#           use case  Cfp-pred  Cfp-int
# 0     Add a paper.  5.589661      6.0
# 1  Delete a paper.  6.426120      6.0
